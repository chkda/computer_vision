# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pwd
# Out:
# 'F:\\my files\\python files\\neural networks\\computer vision'

# %%
image = cv2.imread('images/yell1.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure()
plt.imshow(image)

# %%
image
# Out:
# array([[[ 81,  73,  52],
#         [ 82,  74,  53],
#         [ 84,  76,  55],
#         ...,
#         [ 91,  79,  53],
#         [ 89,  77,  51],
#         [ 86,  74,  48]],
#
#        [[ 76,  68,  47],
#         [ 78,  70,  49],
#         [ 81,  73,  52],
#         ...,
#         [ 96,  84,  58],
#         [ 94,  82,  56],
#         [ 91,  79,  53]],
#
#        [[ 72,  64,  43],
#         [ 75,  67,  46],
#         [ 79,  71,  50],
#         ...,
#         [101,  89,  63],
#         [ 99,  87,  61],
#         [ 95,  83,  57]],
#
#        ...,
#        [[ 92,  78,  51],
#         [ 95,  81,  54],
#         [102,  88,  61],
#         ...,
#         [101,  87,  61],
#         [ 97,  83,  57],
#         [ 92,  78,  52]],
#
#        [[ 79,  65,  38],
#         [ 74,  60,  33],
#         [ 80,  66,  39],
#         ...,
#         [ 67,  53,  27],
#         [ 59,  45,  19],
#         [ 50,  36,  10]],
#
#        [[ 89,  75,  48],
#         [ 78,  64,  37],
#         [ 81,  67,  40],
# ...

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
plt.imshow(image_gray, cmap='gray')

# %%
image_gray
# Out:
# array([[73, 74, 76, ..., 80, 78, 75],
#        [68, 70, 73, ..., 85, 83, 80],
#        [64, 67, 71, ..., 90, 88, 84],
#        ...,
#        [79, 82, 89, ..., 88, 84, 79],
#        [66, 61, 67, ..., 54, 46, 37],
#        [76, 65, 68, ..., 83, 73, 61]], dtype=uint8)

# %%
image_gray_neg = 256 - 1 - image_gray
image_gray_neg
# Out:
# array([[182, 181, 179, ..., 175, 177, 180],
#        [187, 185, 182, ..., 170, 172, 175],
#        [191, 188, 184, ..., 165, 167, 171],
#        ...,
#        [176, 173, 166, ..., 167, 171, 176],
#        [189, 194, 188, ..., 201, 209, 218],
#        [179, 190, 187, ..., 172, 182, 194]], dtype=uint8)

# %%
cv2.imshow('tab', image_gray_neg)
cv2.waitKey()
cv2.destroyWindow('tab')

# %%
image_neg = 256 - 1 - image
image_neg
# Out:
# array([[[174, 182, 203],
#         [173, 181, 202],
#         [171, 179, 200],
#         ...,
#         [164, 176, 202],
#         [166, 178, 204],
#         [169, 181, 207]],
#
#        [[179, 187, 208],
#         [177, 185, 206],
#         [174, 182, 203],
#         ...,
#         [159, 171, 197],
#         [161, 173, 199],
#         [164, 176, 202]],
#
#        [[183, 191, 212],
#         [180, 188, 209],
#         [176, 184, 205],
#         ...,
#         [154, 166, 192],
#         [156, 168, 194],
#         [160, 172, 198]],
#
#        ...,
#        [[163, 177, 204],
#         [160, 174, 201],
#         [153, 167, 194],
#         ...,
#         [154, 168, 194],
#         [158, 172, 198],
#         [163, 177, 203]],
#
#        [[176, 190, 217],
#         [181, 195, 222],
#         [175, 189, 216],
#         ...,
#         [188, 202, 228],
#         [196, 210, 236],
#         [205, 219, 245]],
#
#        [[166, 180, 207],
#         [177, 191, 218],
#         [174, 188, 215],
# ...

# %%
cv2.imshow('tab1', image_neg)
cv2.waitKey()
cv2.destroyWindow('tab1')

# %%
image_gray_log = np.log((1+image_gray))
image_gray_log.astype(np.float32)
# Out:
# array([[ 4.3046875 ,  4.31640625,  4.34375   , ...,  4.39453125,
#          4.37109375,  4.33203125],
#        [ 4.234375  ,  4.26171875,  4.3046875 , ...,  4.453125  ,
#          4.4296875 ,  4.39453125],
#        [ 4.17578125,  4.21875   ,  4.27734375, ...,  4.51171875,
#          4.48828125,  4.44140625],
#        ...,
#        [ 4.3828125 ,  4.41796875,  4.5       , ...,  4.48828125,
#          4.44140625,  4.3828125 ],
#        [ 4.203125  ,  4.12890625,  4.21875   , ...,  4.0078125 ,
#          3.84960938,  3.63671875],
#        [ 4.34375   ,  4.19140625,  4.234375  , ...,  4.4296875 ,
#          4.3046875 ,  4.12890625]], dtype=float32)

# %%
#cv2.imshow('tab2', image_gray_log)
#cv2.waitKey()
#cv2.destroyWindow('tab2')
plt.figure()
plt.subplot(1,2,1)
plt.imshow(image_gray_log, cmap='gray')
plt.subplot(1,2,2)
plt.imshow(image_gray, cmap='gray')

# %%
image_log = np.log((1+image))
image_log.astype('float32')
# Out:
# C:\Users\ckd08\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# array([[[ 4.40625   ,  4.3046875 ,  3.97070312],
#         [ 4.41796875,  4.31640625,  3.98828125],
#         [ 4.44140625,  4.34375   ,  4.0234375 ],
#         ...,
#         [ 4.5234375 ,  4.3828125 ,  3.98828125],
#         [ 4.5       ,  4.35546875,  3.95117188],
#         [ 4.46484375,  4.31640625,  3.89257812]],
#
#        [[ 4.34375   ,  4.234375  ,  3.87109375],
#         [ 4.37109375,  4.26171875,  3.91210938],
#         [ 4.40625   ,  4.3046875 ,  3.97070312],
#         ...,
#         [ 4.57421875,  4.44140625,  4.078125  ],
#         [ 4.5546875 ,  4.41796875,  4.04296875],
#         [ 4.5234375 ,  4.3828125 ,  3.98828125]],
#
#        [[ 4.2890625 ,  4.17578125,  3.78515625],
#         [ 4.33203125,  4.21875   ,  3.84960938],
#         [ 4.3828125 ,  4.27734375,  3.93164062],
# ...

# %%
type(image_log)
# Out:
# numpy.ndarray

# %%
image_gray_gamma = image_gray**2

# %%
cv2.imshow('img', image_gray_gamma)
cv2.waitKey()
cv2.destroyAllWindows()
